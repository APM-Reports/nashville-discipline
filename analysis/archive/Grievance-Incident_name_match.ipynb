# %% [markdown]
# We want to do a preliminary analysis of the grievances and disciplinary data to see if there is a smoke signal in the discipline data.
#
# We'll use the fuzzywuzzy string matching functions to match similar names.

# %%
import os
import json
import pandas as pd
import altair as alt
from fuzzywuzzy import process

cwd = os.getcwd()
data_dir = os.path.join(cwd, 'data')
source_dir = os.path.join(data_dir,'source')
manual_dir = os.path.join(data_dir, 'manual')
processed_dir = os.path.join(data_dir, 'processed')

# the discipline data that is one-row-per-incident
incident_xlsx = os.path.join(source_dir, '2010-2020.xlsx')
incident_df = pd.read_excel(
    incident_xlsx,
    parse_dates = ['FINAL DISP DATE']
)

# grievance data has been manually cleaned 
grievance_csv = os.path.join(manual_dir, 'officer_grievances_cleaned.csv')
grievance_df = pd.read_csv(
    grievance_csv,
    parse_dates = ['date']
)

# %%
grievance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   important_grievance  90 non-null     int64
#  1   control_number       89 non-null     object
#  2   date                 88 non-null     datetime64[ns]
#  3   last_name            90 non-null     object
#  4   first_name           89 non-null     object
#  5   gender               82 non-null     object
#  6   race                 82 non-null     object
#  7   grievance            90 non-null     object
#  8   status               76 non-null     object
#  9   second_stage         40 non-null     object
#  10  notes                11 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 7.9+ KB

# %%
incident_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12896 entries, 0 to 12895
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CONTROL #            12895 non-null  object
#  1   FINAL DISP DATE      12896 non-null  datetime64[ns]
#  2   FINAL DISPOSITION    12896 non-null  object
#  3   FINAL # DAYS         2669 non-null   float64
#  4   EMPLOYEE LAST NAME   12895 non-null  object
#  5   EMPLOYEE FIRST NAME  12854 non-null  object
#  6   ALLEGATION           12888 non-null  object
#  7   COMP SEX             9360 non-null   object
#  8   COMP RACE            9184 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 906.9+ KB

# %% [markdown]
# We need the full names to match

# %%
grievance_df['full_name'] = grievance_df['first_name'] + ' ' + grievance_df['last_name']

incident_df['full_name'] = incident_df['EMPLOYEE FIRST NAME'] + ' ' + incident_df['EMPLOYEE LAST NAME']

# %%
incident_df['full_name'].value_counts()
# Out:
# RONALD BRIGHT        44
# UNKNOWN UNKNOWN      41
# WILLIAM WHITWORTH    40
# BRANDON EVANS        39
# WILLIE REAVES        36
#                      ..
# ROBERT DEBERRY        1
# MARVIN CHAVOUS        1
# DAVID IMHOF           1
# TIFFANY HANSEN        1
# BRANDON MASON         1
# Name: full_name, Length: 2508, dtype: int64

# %%
# There is a null full name in the grievance DF that causes a lot of consternation. We drop it because we can't use it. 

grievance_df = grievance_df.dropna(subset=['full_name']).copy()

# %%
def extract_best_match(name, list_incident_names = (incident_df.full_name.unique())):
    results = process.extract(
        name,
        list_incident_names,
        limit=10
    )
    
    best_result_score = results[0][1] # [0][1] gets the score of the best match for the name
    
    if best_result_score == 100: # indicates perfect match
        best_result_name = results[0][0]
        
        return best_result_name
    else:
        print(name)
        print(results)
        print('enter the index of the best match, n if no match:')
        best_result_index = input()
        
        if best_result_index == 'n':
            return "no discipline"
        else:
            best_result_name = results[int(best_result_index)][0]
            return best_result_name

# %%
# dropna because it causes errors in the fuzzywuzzy functions 
grievance_name_list = (grievance_df.full_name.dropna().unique())

# define the name of the json we'll save the matching-dictionary to. That way we'll only need to do it once
all_name_matches_json = os.path.join(processed_dir, 'all_name_matches.json')

# if the file doesn't exist, do the work to create it
if not os.path.isfile(all_name_matches_json):
    all_name_matches = {}

    for name in grievance_name_list:
        all_name_matches[name] = extract_best_match(name)
    
    with open(all_name_matches_json, 'w') as f:
        json.dump(all_name_matches, f)

# if the file does exist, load it as a dict
if os.path.isfile(all_name_matches_json):
    with open(all_name_matches_json, 'r') as f:
        all_name_matches = json.load(f)

# %%
grievance_df['name_match'] = grievance_df.apply(
    lambda x: all_name_matches[x['full_name']],
    axis=1
)

# %%
###

# %% [markdown]
# There are 80 officers on the grievance list. 20 of those officers (25%) have never faced any discipline.

# %%
len(grievance_name_list)
# Out:
# 80

# %%
grievance_df[['full_name', 'name_match']].drop_duplicates().name_match.value_counts()
# Out:
# no discipline      20
# KEVIN COOLEY        1
# NEIL COOK           1
# LYNSIE SMITH        1
# CYRETHA FRAZIER     1
#                    ..
# ROBERT HOWSE        1
# JUSTIN COKER        1
# DAVID STANLEY       1
# DEVON POWELL        1
# EDWARD HOLLIDAY     1
# Name: name_match, Length: 61, dtype: int64

# %% [markdown]
# A more accurate measure would be only looking at the grievances that we consider important.
#
#
# 35 officers filed grievances that we think may be relevant. 9 of those 35 (25.7%) never faced any discipline.

# %%
important  = grievance_df[grievance_df.important_grievance==1].copy()

# %%
len(important.full_name.unique())
# Out:
# 35

# %%
important[['full_name', 'name_match']].drop_duplicates().name_match.value_counts()
# Out:
# no discipline       9
# DAVID STANLEY       1
# SHARISSA PEREZ      1
# CHRISTINE DAVIS     1
# MONICA BLAKE        1
# GBEWA MUSTAPHA      1
# ROBERT HOWSE        1
# ANITA LOCKRIDGE     1
# TAYLOR HURLEY       1
# VICTORIA LONG       1
# KATHY LEWIS         1
# ANGELA HERRERA      1
# JULIE RIGGS         1
# DEVON POWELL        1
# MADISON MEISS       1
# BRITTANY MCELWEE    1
# CHRISTINE OLSON     1
# CYRETHA FRAZIER     1
# DHANA JONES         1
# Valerie Wilks       1
# CITLALY GOMEZ       1
# ANTIGONA GASHI      1
# PHILLIP SMITH       1
# ANTHONY WILFERT     1
# BARRETT TEAGUE      1
# LYNSIE SMITH        1
# LAURA WALL          1
# Name: name_match, dtype: int64

# %%
# calculates the closest date to the incident date 
# operates on a per-row-basis
def calculate_closest_date(df):
    grievance_name = df.name_match
    grievance_date = df.date
    
    
    if grievance_name == 'no discipline':
        return pd.NaT
    else: 
        # get a list of all the discipline dates using the name match from extract_best_match
        incident_dates = incident_df[
            incident_df.full_name == grievance_name
        ]['FINAL DISP DATE'].to_list()
        
        # map a timedelta lambda over the list of discipline dates
        # the lamda takes the date of the discipline and subtracts the date of the grievance. 
        # That gives us the number of days from the grievance to the discipline 
        list_timedelta = list(
            map(
                lambda x: x - grievance_date,
                incident_dates
            )
        )
        
        # inline if-statement to get only the positive days (grievance happened before discipline)
        positive_list_timedelta = [i for i in list_timedelta if i.days >= 0]
        
        # no positive dates: no discipline after grievance, only before 
        if len(positive_list_timedelta) == 0:
            return pd.NaT
        
        # take the smallest number of days 
        else:
            return min(positive_list_timedelta)

# %%
important
# Out:
#     important_grievance control_number       date  last_name  first_name  \
# 0                     1          11-01 2011-11-17       Long      Vickie
# 1                     1          11-02 2011-11-18   Peterson    Michelle
# 2                     1          01-12 2012-01-18   Peterson    Michelle
# 3                     1          05-01 2012-05-21    Wilfert     Anthony
# 4                     1          08-01 2012-08-15     Jordan  Jacqueline
# 5                     1          08-02 2012-08-24      Lewis       Kathy
# 6                     1          11-01 2012-11-07      Olson   Christine
# 7                     1           1201 2016-12-16      Howse      Robert
# 8                     1      201701-01 2017-01-03      James     Jasmine
# 9                     1      201702-01 2017-02-21      Smith   Philip R.
# 10                    1      201705-01        NaT      Howse      Robert
# 11                    1      201705-02 2017-04-27     Teague     Barrett
# 12                    1      201706-01 2017-06-19     Teague     Barrett
# 13                    1      201707-01 2017-06-24      Howse      Robert
# 14                    1       20170803 2017-08-28  Lockridge       Anita
# 15                    1       20171001 2017-10-19  Lockridge       Anita
# 16                    1       20171102 2017-11-29     Blake       Monica
# 17                    1       20171203 2017-12-12     Blake       Monica
# 18                    1       20171201 2017-12-13      Riggs       Julie
# 19                    1       20180201 2018-02-08     Powell       Devon
# 20                    1       20180501 2018-05-11      Perez    Sharissa
# 21                    1       20180601 2018-06-21     Smith       Lynsie
# 22                    1       20180602 2018-06-21  Mustapha        Gweba
# 23                    1       20180801 2018-08-29    McElwee    Brittany
# 24                    1       20180802 2018-08-29      Meiss     Madison
# 25                    1       20180803 2018-08-30     Hurley      Taylor
# 26                    1       20181001 2018-10-09      Davis   Christine
# 27                    1       20181102 2018-11-06      Jones       Dhana
# 28                    1       20181201 2018-12-11    Sneekes   Christina
# 29                    1       20190101 2019-02-05   Anderson   Markeshia
# 30                    1       20190102 2019-02-04     Bolden       Carol
# 31                    1       20190701 2019-07-01    Herrera      Angela
# 32                    1       20190901 2019-09-11   Phillips      Tamara
# 33                    1       20191001 2019-10-02      Gomez      Citaly
# 34                    1            NaN 2020-01-16     Young        Tonya
# 35                    1       20200601 2020-06-04      Gashi    Antigona
# 36                    1       20200602 2020-06-11      Wilks     Valerie
# 37                    1       20210201 2021-02-08    Huggins   J. Damian
# 38                    1       20210202        NaT       Wall       Laura
# 39                    1       20210301 2021-03-04   Frazier      Cyretha
# 40                    1       20210302 2021-03-05    Stanley       David
#
#    gender race                                 grievance  \
# 0       F    H                       Denial of IOD Claim
# 1     NaN  NaN       Unprofessional conduct - Supervisor
# 2     NaN  NaN      Retaliation - unprofessional conduct
# 3       M    W                 Discrimination/harassment
# 4       F    B                            Discrimination
# 5       F    B                               AWOL Status
# 6       F    W                        Employee Relations
# 7       M    B                         unfair discipline
# 8       F    B         harassment and workplace bullying
# 9       M    W                                Harassment
# 10      M    B                                harassment
# 11      M    W                         sexual harassment
# 12      M    W                               retaliation
# 13      M    B                               retaliation
# 14      F    B                            discrimination
# 15      F    B                               retaliation
# 16      F    B                  hostile work enviornment
# 17      F    B          performance evaluation procedure
# 18      F    W                  hostile work enviornment
# 19      F    B                  hostile work enviornment
# 20      F    H                         sexual harassment
# 21      F    W             Harassment and Discrimination
# 22      M    B             Harassment and Discrimination
# 23      F    W                             Discimination
# 24      F    W                             Discimination
# 25      F    W                             Discimination
# 26      F    B                  hostile work enviornment
# 27      F    B                               retaliation
# 28      F    W                            discrimination
# 29      F    B                               retaliation
# 30      F    B                               retaliation
# 31      F    H      retaliation/hostile work enviornment
# 32      F    W                         sexual harassment
# 33      F    H                         sexual harassment
# 34      F    B                         sexual harassment
# 35      F    W  hostile work enviornment/national origin
# 36      F    B                  hostile work enviornment
# 37      M    W                                  demotion
# 38      F    W                  hostile work enviornment
# 39      F    W                  hostile work enviornment
# 40      M    W                            discrimination
#
#                                                status  \
# 0                  Stage 1 - Conducting investigation
# 1   Stage 1 -2 issues substantiated - 1 can not be...
# 2          Investigating - Have an extenstion 1/18/12
# 3   Claim cannot be substantiated - Stage 1 given ...
# 4       Turned over to OPA on Monday, August 20, 2012
# 5   Stage 1 - Letter - Resolution possible team tr...
# 6       Stage 1 Letter - Not substantiated - 11-14-12
# 7                                 letter sent 1/13/17
# 8                  not sustained/ letter sent 3-22-17
# 9                   not sustained/ letter sent 5/8/17
# 10   not sustained/letter sent by Sue Bibb on 5/25/17
# 11  Stage I letter by Sue Bibb 5/31/17; Appeal to ...
# 12  Appeal from 05-02 contained retaliation claim....
# 13             Stage I letter 7/14/17; Letter 7/20/17
# 14                                                NaN
# 15                          A Violation Did Not Occur
# 16                          A Violation Did Not Occur
# 17                               A Violation Occurred
# 18                          A Violation Did Not Occur
# 19                               A Violation Occurred
# 20                               A Violation Occurred
# 21                               A Violation Occurred
# 22                               A Violation Occurred
# 23                               A Violation Occurred
# 24                               A Violation Occurred
# 25                               A Violation Occurred
# 26                               A Violation Occurred
# 27                          A Violation Did Not Occur
# 28                          A Violation Did Not Occur
# 29                                                NaN
# 30                                                NaN
# 31                          A Violation Did Not Occur
# 32                               A Violation Occurred
# 33                               A Violation Occurred
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37    An Application Neither Occurred Nor Should Have
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
#
#                                          second_stage               notes  \
# 0    letter 12/13/11 - She was out on leave - IOD ...                 NaN
# 1                                     letter 1/17/12   Resolved - 1/18/12
# 2                                     Resolved 3-5-12                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6             Did not appeal by 11-27-12- Case Closed                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                               letter signed 3/6/18                 NaN
# 17   letter 3/20/18 - updated evaluation not received                 NaN
# 18                              letter signed 3-26-18                 NaN
# 19                              Letter signed 3-12-18                 NaN
# 20                               letter sent 6/8/2018                 NaN
# 21                                   presented 4/5/19                 NaN
# 22                                   presented 4/5/19                 NaN
# 23                                   presented 4/5/19                 NaN
# 24                                                NaN                 NaN
# 25                                                NaN                 NaN
# 26                                                NaN                 NaN
# 27                           withdrawn by complainant                 NaN
# 28                                                NaN                 NaN
# 29                                          mediation                 NaN
# 30                                          mediation                 NaN
# 31                                        letter sent                 NaN
# 32                                stage 1 letter sent                 NaN
# 33                                stage 1 letter sent                 NaN
# 34         Transferred to Sex Crimes per DCOP Huggins                 NaN
# 35        Reassigned to OPA/Back to HR for completion                 NaN
# 36        DCOP Huggins declined stage 1 investigation                 NaN
# 37                               letter sent  2/11/21                 NaN
# 38                                                NaN                 NaN
# 39                                                NaN                 NaN
# 40                                                NaN                 NaN
#
#              full_name        name_match time_to_discipline
# 0          Vickie Long     VICTORIA LONG           393 days
# 1    Michelle Peterson     no discipline                NaT
# 2    Michelle Peterson     no discipline                NaT
# 3      Anthony Wilfert   ANTHONY WILFERT            50 days
# 4    Jacqueline Jordan     no discipline                NaT
# 5          Kathy Lewis       KATHY LEWIS            18 days
# 6      Christine Olson   CHRISTINE OLSON           496 days
# 7         Robert Howse      ROBERT HOWSE           108 days
# 8        Jasmine James     no discipline                NaT
# 9      Philip R. Smith     PHILLIP SMITH                NaT
# 10        Robert Howse      ROBERT HOWSE                NaT
# 11      Barrett Teague    BARRETT TEAGUE            78 days
# 12      Barrett Teague    BARRETT TEAGUE            25 days
# 13        Robert Howse      ROBERT HOWSE            96 days
# 14     Anita Lockridge   ANITA LOCKRIDGE            78 days
# 15     Anita Lockridge   ANITA LOCKRIDGE            26 days
# 16       Monica Blake       MONICA BLAKE           266 days
# 17       Monica Blake       MONICA BLAKE           253 days
# 18         Julie Riggs       JULIE RIGGS           294 days
# 19        Devon Powell      DEVON POWELL            19 days
# 20      Sharissa Perez    SHARISSA PEREZ           153 days
# 21       Lynsie Smith       LYNSIE SMITH            88 days
# 22     Gweba Mustapha     GBEWA MUSTAPHA            88 days
# 23    Brittany McElwee  BRITTANY MCELWEE           478 days
# 24       Madison Meiss     MADISON MEISS            14 days
# 25       Taylor Hurley     TAYLOR HURLEY            93 days
# 26     Christine Davis   CHRISTINE DAVIS           140 days
# 27         Dhana Jones       DHANA JONES           442 days
# 28   Christina Sneekes     no discipline                NaT
# 29  Markeshia Anderson     no discipline                NaT
# 30        Carol Bolden     no discipline                NaT
# 31      Angela Herrera    ANGELA HERRERA           205 days
# 32     Tamara Phillips     no discipline                NaT
# 33        Citaly Gomez     CITLALY GOMEZ           306 days
# 34        Tonya Young      no discipline                NaT
# 35      Antigona Gashi    ANTIGONA GASHI                NaT
# 36       Valerie Wilks     Valerie Wilks                NaT
# 37   J. Damian Huggins     no discipline                NaT
# 38          Laura Wall        LAURA WALL                NaT
# 39    Cyretha Frazier    CYRETHA FRAZIER                NaT
# 40       David Stanley     DAVID STANLEY                NaT

# %%
important['time_to_discipline'] = important.apply(calculate_closest_date, axis=1)

# %%
len(important)
# Out:
# 41

# %% [markdown]
# 17 of the important grievances either had no discipline filed against the officer at all or no discipline post-grievance.
#
# 24 of the important grievances _did_ face discipline after the fact, some as soon as 14 days

# %%
important.time_to_discipline.value_counts(dropna=False)
# Out:
# NaT         17
# 88 days      2
# 78 days      2
# 140 days     1
# 18 days      1
# 14 days      1
# 478 days     1
# 266 days     1
# 205 days     1
# 496 days     1
# 253 days     1
# 153 days     1
# 442 days     1
# 25 days      1
# 96 days      1
# 108 days     1
# 294 days     1
# 26 days      1
# 306 days     1
# 393 days     1
# 19 days      1
# 50 days      1
# 93 days      1
# Name: time_to_discipline, dtype: int64

# %%
important.time_to_discipline.value_counts().sum()
# Out:
# 24

# %%
important.groupby('gender').time_to_discipline.agg(lambda x: x.mean())
# Out:
# gender
# F   209 days 00:00:00
# M    74 days 04:00:00
# Name: time_to_discipline, dtype: timedelta64[ns]

# %%
important.groupby('race').time_to_discipline.agg(lambda x: x.mean())
# Out:
# race
# B   139 days 10:54:32.727272728
# H             264 days 06:00:00
# W             179 days 13:20:00
# Name: time_to_discipline, dtype: timedelta64[ns]

# %%
important.groupby(['gender','race']).time_to_discipline.agg(lambda x: x.mean())
# Out:
# gender  race
# F       B      155 days 06:00:00
#         H      264 days 06:00:00
#         W      243 days 20:00:00
# M       B       97 days 08:00:00
#         W       51 days 00:00:00
# Name: time_to_discipline, dtype: timedelta64[ns]
