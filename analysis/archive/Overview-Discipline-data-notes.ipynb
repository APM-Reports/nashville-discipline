# %% [markdown]
# # Discipline Data Notes
#
# In June, reporter Samantha Max requested what is supposed to be the definitive list of discipline data for the Metro Nashville Police Department.
#
# Here are notes about the file and a summary of possible issues we will have with the data.
#
#
# This is an overview of the discipline data that came as one-row-per-charge/

# %%
import os
import pandas as pd
import altair as alt

cwd = os.getcwd()
data_dir = os.path.join(cwd, 'data')
source_dir = os.path.join(data_dir,'source')
processed_dir = os.path.join(data_dir, 'processed')
pkl_dir = os.path.join(processed_dir,'pkl')

# Data is an xls file, so we won't be using read_csv 
discipline_xls = os.path.join(source_dir, 'Report 6-14-21 Data Request.xls')

# %%
# There are a lot of column datatypes to assign and column names to change 

info = {
    'dtypes' : {
        'Off: ENO': 'object', 
        'Off: Badge/ID number': 'object', 
        'Off: First name': 'object',
        'Off: Middle name': 'object', 
        'Off: Last name': 'object', 
        'Off: Race': 'category', 
        'Off: Sex': 'category',
        'Off: Title': 'object', 
        'Alleg: Allegation': 'object', 
        'Alleg: Finding': 'object',
        'Act: Action taken': 'object', 
        'Act: Narrative': 'object'
    },
    'columns' : { 
        'Off: Date hired': 'date_hired', 
        'Off: ENO': 'officer_employee_num', 
        'Off: Badge/ID number': 'badge_num',
        'Off: Date-of-birth': 'date_birth', 
        'Off: Employment end date': 'date_employment_over', 
        'Off: First name': 'first_name',
        'Off: Middle name': 'middle_name', 
        'Off: Last name': 'last_name', 
        'Off: Race': 'race', 
        'Off: Sex': 'sex',
        'Off: Title': 'title', 
        'Alleg: Allegation': 'allegation', 
        'Alleg: Finding': 'finding',
        'Act: Action taken': 'action_taken', 
        'Act: Action taken date': 'date_action_taken', 
        'Act: Narrative': 'narrative'
    }
}

# %%
# datetypes are assigned on import by passing a list to parse dates
discipline_df = pd.read_excel(
    discipline_xls,
    parse_dates = [
        'Off: Date hired',
        'Off: Date-of-birth',
        'Off: Employment end date',
        'Act: Action taken date'
    ],
    dtype=info['dtypes']
)

discipline_df = discipline_df.rename(columns=info['columns'])

discipline_df.to_pickle(
    os.path.join(pkl_dir, 'cleaned_new_discipline_data.pkl')
)

# %% [markdown]
# ## Overview
# There are 16 columns with 50,406 rows. The data comes with a lot of missing values.

# %%
discipline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50406 entries, 0 to 50405
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_hired            50008 non-null  datetime64[ns]
#  1   officer_employee_num  50373 non-null  object
#  2   badge_num             49048 non-null  object
#  3   date_birth            49998 non-null  datetime64[ns]
#  4   date_employment_over  17046 non-null  datetime64[ns]
#  5   first_name            50405 non-null  object
#  6   middle_name           45311 non-null  object
#  7   last_name             50405 non-null  object
#  8   race                  50272 non-null  category
#  9   sex                   50302 non-null  category
#  10  title                 50204 non-null  object
#  11  allegation            32850 non-null  object
#  12  finding               30156 non-null  object
#  13  action_taken          17779 non-null  object
#  14  date_action_taken     17610 non-null  datetime64[ns]
#  15  narrative             16853 non-null  object
# dtypes: category(2), datetime64[ns](4), object(10)
# memory usage: 5.5+ MB

# %% [markdown]
# There is one row that is completely empty so we'll drop it

# %%
discipline_df[discipline_df.isnull().all(1)]
# Out:
#       date_hired officer_employee_num badge_num date_birth  \
# 29027        NaT                  NaN       NaN        NaT
#
#       date_employment_over first_name middle_name last_name race  sex title  \
# 29027                  NaT        NaN         NaN       NaN  NaN  NaN   NaN
#
#       allegation finding action_taken date_action_taken narrative
# 29027        NaN     NaN          NaN               NaT       NaN

# %%
discipline_df = discipline_df.drop([29027])

# %% [markdown]
# ## Duplicate Rows - what is one row in this dataset?
#
# Inspecting the data, it looks like there are a lot of duplicate rows. That raises the important question of what one row in the dataset represents.
#
# For example, Michael Dudley has 8 rows associated with the allegation 'zDNU - Adherence to Law (13)' with an action taken on 3/31/2017. There are two action takens. Why are there 8 rows and what do the duplicates mean? Do we have a way of narrowing down to a single allegation? A single discpline? This might not be an issue, with more information.

# %%
dudley_mask = (discipline_df.first_name == 'Michael')\
& (discipline_df.last_name == 'Dudley')\
& (discipline_df.allegation =='zDNU - Adherence to Law (13)')

discipline_df[dudley_mask]
# Out:
#     date_hired officer_employee_num badge_num date_birth date_employment_over  \
# 3   2001-02-16               402646     39581 1970-09-25           2018-11-17
# 4   2001-02-16               402646     39581 1970-09-25           2018-11-17
# 7   2001-02-16               402646     39581 1970-09-25           2018-11-17
# 8   2001-02-16               402646     39581 1970-09-25           2018-11-17
# 11  2001-02-16               402646     39581 1970-09-25           2018-11-17
# 12  2001-02-16               402646     39581 1970-09-25           2018-11-17
# 928 2001-02-16               402646     39581 1970-09-25           2018-11-17
# 929 2001-02-16               402646     39581 1970-09-25           2018-11-17
#
#     first_name middle_name last_name   race   sex title  \
# 3      Michael           L    Dudley  White  Male    PO
# 4      Michael           L    Dudley  White  Male    PO
# 7      Michael           L    Dudley  White  Male    PO
# 8      Michael           L    Dudley  White  Male    PO
# 11     Michael           L    Dudley  White  Male    PO
# 12     Michael           L    Dudley  White  Male    PO
# 928    Michael           L    Dudley  White  Male    PO
# 929    Michael           L    Dudley  White  Male    PO
#
#                        allegation                   finding  \
# 3    zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 4    zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 7    zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 8    zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 11   zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 12   zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 928  zDNU - Adherence to Law (13)  Agree w/Recommended Disc
# 929  zDNU - Adherence to Law (13)  Agree w/Recommended Disc
#
#                         action_taken date_action_taken  \
# 3               zDNU - Suspend/Demot        2017-03-31
# 4               zDNU - Suspend/Demot        2017-03-31
# 7               zDNU - Suspend/Demot        2017-03-31
# 8               zDNU - Suspend/Demot        2017-03-31
# 11   zDNU - See 313-313A Disc Action        2017-03-31
# 12   zDNU - See 313-313A Disc Action        2017-03-31
# 928  zDNU - See 313-313A Disc Action        2017-03-31
# 929  zDNU - See 313-313A Disc Action        2017-03-31
#
#                                              narrative
# 3    Suspend/Demot\r\nAction Taken Detials: FIVE (5...
# 4    Suspend/Demot\r\nAction Taken Detials: FIVE (5...
# 7    Suspend/Demot\r\nAction Taken Detials: FIVE (5...
# 8    Suspend/Demot\r\nAction Taken Detials: FIVE (5...
# 11   SEE 313-313A DISC ACTION\r\nAction Taken Detia...
# 12   SEE 313-313A DISC ACTION\r\nAction Taken Detia...
# 928  SEE 313-313A DISC ACTION\r\nAction Taken Detia...
# 929  SEE 313-313A DISC ACTION\r\nAction Taken Detia...

# %% [markdown]
# ## Badge Number and Employee Number
#
# Badge Number and Employee Number are necessary to do a proper matching between a roster of officers and the discipline data. We should use employee number because it is more complete.

# %% [markdown]
# #### Employee Number
# Employee number is nearly complete. There are only 32 null values, representing 23 employees.

# %%
null_employee_nums = discipline_df[discipline_df.officer_employee_num.isna()]

null_employee_nums
# Out:
#       date_hired officer_employee_num badge_num date_birth  \
# 11168 2020-02-16                  NaN       NaN 1994-12-08
# 11169 2020-02-16                  NaN       NaN 1994-12-08
# 13097 2018-10-16                  NaN       NaN 1985-01-09
# 14219        NaT                  NaN       NaN        NaT
# 15177 2019-08-16                  NaN       NaN 1996-04-06
# 15232        NaT                  NaN       NaN        NaT
# 19512 2019-08-16                  NaN       NaN 1993-07-04
# 21945 1992-08-23                  NaN       NaN 1992-08-23
# 21946 1992-08-23                  NaN       NaN 1992-08-23
# 22894 1991-05-01                  NaN       NaN 1991-11-30
# 25187        NaT                  NaN   4001442        NaT
# 25188        NaT                  NaN   4001442        NaT
# 26391 2019-03-16                  NaN       NaN 1996-02-12
# 27869 2019-03-16                  NaN       NaN 1996-09-27
# 30723 2019-03-16                  NaN       NaN 1992-04-09
# 37195        NaT                  NaN    309262        NaT
# 37196        NaT                  NaN    309262        NaT
# 39246 2019-03-16                  NaN       NaN 1992-04-09
# 39247 2019-03-16                  NaN       NaN 1992-04-09
# 39795 2020-02-16                  NaN       NaN 1996-03-15
# 40122        NaT                  NaN       NaN        NaT
# 41952 2019-08-16                  NaN       NaN 1995-04-09
# 43487 2019-03-16                  NaN       NaN 1994-02-20
# 43571 2019-03-16                  NaN       NaN 1991-06-08
# 43605        NaT                  NaN       NaN        NaT
# 44484 2019-08-16                  NaN       NaN 1996-05-21
# 44502 2019-03-16                  NaN       NaN 1992-04-23
# 47265 2019-08-16                  NaN       NaN 1993-07-04
# 47681 2019-03-16                  NaN       NaN        NaT
# 48404        NaT                  NaN       NaN        NaT
# 48405        NaT                  NaN       NaN        NaT
# 49574 2019-03-16                  NaN       NaN 1992-04-23
#
#       date_employment_over    first_name middle_name     last_name  \
# 11168                  NaT        Dillon         NaN          Gann
# 11169                  NaT        Dillon         NaN          Gann
# 13097           2019-08-16        Justin         NaN       Spencer
# 14219                  NaT         David         NaN         Harms
# 15177                  NaT        Dallas         NaN       Johnson
# 15232                  NaT       HARHEEN           R         YUNUS
# 19512                  NaT       Matthew           E         Herod
# 21945                  NaT       Cameron         NaN        Schmid
# 21946                  NaT       Cameron         NaN        Schmid
# 22894                  NaT       Michael         NaN       Sposito
# 25187                  NaT       Vincent         NaN       McCrary
# 25188                  NaT       Vincent         NaN       McCrary
# 26391                  NaT        Rachel           J        Willis
# 27869                  NaT         MARIO        LUIS          Diaz
# 30723                  NaT         Brian         NaN       Quigley
# 37195                  NaT         Jacob         NaN       Krispin
# 37196                  NaT         Jacob         NaN       Krispin
# 39246                  NaT         Brian         NaN       Quigley
# 39247                  NaT         Brian         NaN       Quigley
# 39795                  NaT          Ryan           D          Papp
# 40122                  NaT         jacob         NaN       krispin
# 41952                  NaT          Beri      Symone         Scott
# 43487                  NaT        Robert        John  Higgins, Jr.
# 43571                  NaT  Lawerence II           L        Whited
# 43605                  NaT          Chad        Alan       Connors
# 44484                  NaT      Mckenzie           I        Harper
# 44502           2020-01-04       William         NaN     Cleveland
# 47265                  NaT       Matthew           E         Herod
# 47681                  NaT       Garrett       James         Short
# 48404                  NaT       Patrick       Glenn       Hubbard
# 48405                  NaT       Patrick       Glenn       Hubbard
# 49574           2020-01-04       William         NaN     Cleveland
#
#               race     sex  title  \
# 11168        White    Male    POT
# 11169        White    Male    POT
# 13097        White    Male     PT
# 14219        White    Male  PO II
# 15177        White    Male    POT
# 15232          NaN     NaN    NaN
# 19512        White    Male    POT
# 21945        White    Male    NaN
# 21946        White    Male    NaN
# 22894        White    Male    POT
# 25187        Black    Male    POT
# 25188        Black    Male    POT
# 26391        White  Female    POT
# 27869     Hispanic    Male    POT
# 30723        White    Male    POT
# 37195          NaN     NaN    NaN
# 37196          NaN     NaN    NaN
# 39246        White    Male    POT
# 39247        White    Male    POT
# 39795        White    Male    POT
# 40122          NaN     NaN    NaN
# 41952        Black  Female    POT
# 43487        White  Female    POT
# 43571  Black/White    Male    POT
# 43605        White    Male  PO II
# 44484        White    Male    POT
# 44502        White    Male    POT
# 47265        White    Male    POT
# 47681        White    Male  PO II
# 48404        Black    Male  PO II
# 48405        Black    Male  PO II
# 49574        White    Male    POT
#
#                                               allegation            finding  \
# 11168  MNPD Manual 4.20.050 K Use of Alcohol, Drugs o...                NaN
# 11169  MNPD Manual 4.20.040 D Conduct Unbecoming an E...                NaN
# 13097  MNPD Manual 4.20.040 A Adherence to Policy & R...          Sustained
# 14219                    MNPD Manual 4.20.040 G Courtesy                NaN
# 15177       MNPD Manual 4.20.040 K Obstruction of Rights                NaN
# 15232  MNPD Manual 4.20.040 A Adherence to Policy & R...          Sustained
# 19512                                                NaN                NaN
# 21945  MNPD Manual 4.20.040 A Adherence to Policy & R...                NaN
# 21946  MNPD Manual 4.20.040 A Adherence to Policy & R...                NaN
# 22894  MNPD Manual 4.20.040 A Adherence to Policy & R...          Sustained
# 25187  MNPD Manual 4.20.040 A Adherence to Policy & R...                NaN
# 25188  MNPD Manual 4.20.040 A Adherence to Policy & R...                NaN
# 26391  MNPD Manual 4.20.040 A Adherence to Policy & R...          Sustained
# 27869             MNPD Manual 4.40 Biased Based Policing          Unfounded
# 30723                    MNPD Manual 4.20.040 G Courtesy                NaN
# 37195                                                NaN                NaN
# 37196  MNPD Manual 4.20.050 F Deficient or Inefficien...          Unfounded
# 39246  MNPD Manual 4.20.050 H Absent Without Leave (A...          Unfounded
# 39247  MNPD Manual 4.20.050 F Deficient or Inefficien...         Exonerated
# 39795                                                NaN                NaN
# 40122                                                NaN                NaN
# 41952                                                NaN                NaN
# 43487              MNPD Manual 4.20.040 L Discrimination                NaN
# 43571                                                NaN                NaN
# 43605                                                NaN                NaN
# 44484                    MNPD Manual 4.20.040 G Courtesy                NaN
# 44502                    MNPD Manual 4.20.040 G Courtesy         Exonerated
# 47265  MNPD Manual 4.20.050 W.1 Care of Government Pr...  Written Reprimand
# 47681                    MNPD Manual 4.20.040 G Courtesy                NaN
# 48404                              MNPD Manual 11.10.010         Exonerated
# 48405  MNPD Manual 4.20.040 D Conduct Unbecoming an E...      Not Sustained
# 49574  MNPD Manual 4.20.050 W.1 Care of Government Pr...          Sustained
#
#             action_taken date_action_taken narrative
# 11168                NaN               NaT       NaN
# 11169                NaN               NaT       NaN
# 13097          Dismissal        2019-08-16       NaN
# 14219                NaN               NaT       NaN
# 15177                NaN               NaT       NaN
# 15232          Dismissal        2018-05-01       NaN
# 19512                NaN               NaT       NaN
# 21945                NaN               NaT       NaN
# 21946                NaN               NaT       NaN
# 22894                NaN               NaT       NaN
# 25187                NaN               NaT       NaN
# 25188                NaN               NaT       NaN
# 26391  Written Reprimand        2019-12-02       NaN
# 27869                NaN               NaT       NaN
# 30723                NaN               NaT       NaN
# 37195                NaN               NaT       NaN
# 37196                NaN               NaT       NaN
# 39246                NaN               NaT       NaN
# 39247                NaN               NaT       NaN
# 39795                NaN               NaT       NaN
# 40122                NaN               NaT       NaN
# 41952                NaN               NaT       NaN
# 43487                NaN               NaT       NaN
# 43571                NaN               NaT       NaN
# 43605                NaN               NaT       NaN
# 44484                NaN               NaT       NaN
# 44502                NaN               NaT       NaN
# 47265                NaN               NaT       NaN
# 47681                NaN               NaT       NaN
# 48404                NaN               NaT       NaN
# 48405                NaN               NaT       NaN
# 49574  Written Reprimand        2019-11-13       NaN

# %%
discipline_df.officer_employee_num.isna().sum()
# Out:
# 32

# %%
len(null_employee_nums.last_name.unique())
# Out:
# 23

# %% [markdown]
# There are 2,590 employee numbers in the data

# %%
len(discipline_df.officer_employee_num.unique())
# Out:
# 2590

# %% [markdown]
# ### Badge Number
# Badge number is less complete than employee number, with 1,357 nulls, or 220 people. Maybe this is because there are people who are not officers in the data.

# %%
null_badge_nums = discipline_df[discipline_df.badge_num.isna()]

null_badge_nums
# Out:
#       date_hired officer_employee_num badge_num date_birth  \
# 407          NaT               226532       NaN        NaT
# 743          NaT               251667       NaN        NaT
# 784          NaT               675829       NaN        NaT
# 868          NaT               179466       NaN        NaT
# 881          NaT               727199       NaN        NaT
# ...          ...                  ...       ...        ...
# 50306 2018-01-16               320581       NaN 1988-09-01
# 50309 2018-10-16               352213       NaN 1996-01-12
# 50338 2018-10-16               352201       NaN 1982-09-27
# 50360        NaT               320600       NaN 1992-01-02
# 50377 2018-01-16               320597       NaN 1991-10-16
#
#       date_employment_over first_name middle_name     last_name   race  \
# 407             2015-01-06    Melissa         Ann       Johnson  White
# 743             2017-01-19   Jennifer         NaN  Parker-Ayers  Black
# 784                    NaT    Stephen     Charles        Fouche  White
# 868                    NaT       Tara         NaN       Thurman  White
# 881                    NaT     Charle          S.         Eaton  White
# ...                    ...        ...         ...           ...    ...
# 50306                  NaT  Johnathan         NaN      Sharp II  White
# 50309                  NaT       Joel         NaN      Cottrill  White
# 50338                  NaT       Eric           L       Jackson  White
# 50360           2019-01-20   Jonathan         NaN         Watch  White
# 50377                  NaT       Sean         NaN        Weaver  White
#
#           sex  title                                         allegation  \
# 407    Female   POII           zDNU - Devoting Entire Time to Duty (09)
# 743    Female  PCCII                     zDNU - Conduct Unbecoming (13)
# 784      Male   POII              zDNU - Adherence2Policy&Rules (New09)
# 868    Female   POAI                             zDNU - Attendance (13)
# 881      Male   PSGT                       zDNU - Care of Property (13)
# ...       ...    ...                                                ...
# 50306    Male     PO                                                NaN
# 50309    Male   POII                                                NaN
# 50338    Male   POII                                                NaN
# 50360    Male     PO                                                NaN
# 50377    Male     PO  MNPD Manual 4.20.040 A Adherence to Policy & R...
#
#                         finding                    action_taken  \
# 407            Matter of Record                     zDNU - None
# 743                   Sustained  zDNU - Resigned w/Under Invest
# 784    Agree w/Recommended Disc               zDNU - Suspension
# 868                Rev'd-Signed        zDNU - Written Reprimand
# 881                Rev'd-Signed        zDNU - Written Reprimand
# ...                         ...                             ...
# 50306                       NaN                             NaN
# 50309                       NaN                             NaN
# 50338                       NaN                             NaN
# 50360                       NaN                             NaN
# 50377                Exonerated                             NaN
#
#       date_action_taken                                          narrative
# 407          2012-09-15  None\r\nAction Taken Detials: due to the compl...
# 743                 NaT  Resigned w/Under Invest\r\nAction Taken Detial...
# 784          2010-05-25  Suspension\r\nAction Taken Detials: One (1) da...
# 868          2017-03-27  Written Reprimand\r\nAction Taken Detials: 065...
# 881          2017-05-09  Written Reprimand\r\nAction Taken Detials: 100...
# ...                 ...                                                ...
# 50306               NaT                                                NaN
# 50309               NaT                                                NaN
# 50338               NaT                                                NaN
# 50360               NaT                                                NaN
# 50377               NaT                                                NaN
#
# [1357 rows x 16 columns]

# %%
discipline_df.badge_num.isna().sum()
# Out:
# 1357

# %%
len(null_badge_nums.last_name.unique())
# Out:
# 220

# %% [markdown]
# There are 2,384 badge numbers in the data

# %%
len(discipline_df.badge_num.unique())
# Out:
# 2384

# %% [markdown]
# ## Race
# There are a lot of values in the race columns. It's possible we could reduce to 4: Black, White, Asian, Hispanic, and Unknown.
#
# We should ask what T and 03 represent, since there are so many of them.
#
# There are 133 rows where there is no officer race.

# %%
discipline_df.race.value_counts(dropna=False)
# Out:
# White              40304
# Black               6899
# T                   1286
# 03                   917
# Asian                658
# NaN                  133
# P                     88
# American Indian       63
# Other                 24
# Hispanic              22
# Black/White            5
# U                      3
# Q                      2
# Latino                 1
# Name: race, dtype: int64

# %% [markdown]
# ## Action Taken
#
# There is no disposition date or accusation date in the data. There is an action taken date, but it is very incomplete. It has 32,626 null rows, which is 64% of the data.

# %%
discipline_df.action_taken.isna().sum()
# Out:
# 32626

# %%
discipline_df.action_taken.isna().sum()/len(discipline_df)
# Out:
# 0.6472770558476342

# %% [markdown]
# Without the date of the allegation/discipline/disposition, we will have a very hard time performing an analysis on whether or not there is any retaliation going on at the department. The reason that we need the date is that it is possible that an officer had a few disciplary actions taken against them before they filed a grievance and no discipline taken after. But without the ability to sort actions into "before" and "after" the grievance, we would be counting all discipline towards the analysis.
#
#
# We could still look at the rate of discipline for officers that filed grievances and those that did not, but we would have to be very clear with the audience that we do not know if the discipline happened before or after the grievance.
#
#
# Let's look at Monica Blake. We know she filed two grievances in 2017. There are 59 rows related to her discipline in the data and 18 of them don't have an associated date and one row has 1990 as the year, which is 15 years before she was hired. That's just about 32% of the rows we'd have to figure out how to handle.

# %%
blake_mask = (discipline_df.first_name == 'Monica')&(discipline_df.last_name == 'Blake')
blake_df = discipline_df[blake_mask]

len(blake_df)
# Out:
# 59

# %%
blake_df.date_action_taken.isna().sum()
# Out:
# 18

# %% [markdown]
# The missing dates don't seem to be evenly distributed. There is a clear pattern to the data that we do have.

# %%
actions_taken = discipline_df.date_action_taken.copy()

data = actions_taken.apply(
    lambda x: x.year
).value_counts().reset_index().rename(columns={'index':'year'})

alt.Chart(data).mark_bar().encode(
    x='year:O',
    y='date_action_taken'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Allegations
#
# There are a lot of blank allegations. 17,556 rows have nothing in the allegation field, so we are unable to determine how to use them to collapse from charges to incident.

# %%
discipline_df.allegation.isna().sum()
# Out:
# 17556

# %% [markdown]
# The allegations are also difficult to reduce from charges to incidents. Manually comparing one name in the new data, John Hatcher, to the old data, shows the difficulty.
#
# There are 12 rows with John Hatcher in the new data and only 4 incidents, based on the old data. But the new data list 5 distinct allegations with many additional blank rows.
